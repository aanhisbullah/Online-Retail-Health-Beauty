# %% [markdown]
# <a href="https://colab.research.google.com/github/aanhisbullah/Online-Retail-Health-Beauty/blob/main/Online_Retail_Health%26Beauty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import excel lalu read dulu
df = pd.read_excel('/content/drive/MyDrive/Dataset Data Analyst/Dope_Retail.xlsx', sheet_name='Online Retail')

# %%
#melihat kolom awal
df.shape
# Out:
# (541909, 8)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1  536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
#pd data frame, buat interaktive table, df[qty] buat milih kolom dan deskripsikan
pd.DataFrame(df['Quantity'].describe())
# Out:
#             Quantity
# count  541909.000000
# mean        9.552250
# std       218.081158
# min    -80995.000000
# 25%         1.000000
# 50%         3.000000
# 75%        10.000000
# max     80995.000000

# %%
pd.DataFrame(df.describe())
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
print(df.corr())
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.001235    -0.00360
# UnitPrice  -0.001235   1.000000    -0.00456
# CustomerID -0.003600  -0.004560     1.00000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 33.1+ MB
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(df.isna().sum())
# Out:
#                   0
# InvoiceNo         0
# StockCode         0
# Description    1454
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID   135080
# Country           0

# %%
# Filter data yang mengandung nilai (null/na)

df_filtered = df.dropna(axis=0) #akan menghapus semua baris yang mengandung nilai null pada DataFrame
#df_filtered = df.dropna(how='any') #akan menghapus baris yang mengandung setidaknya satu nilai null pada DataFrame

# %%
pd.DataFrame(df_filtered.isna().sum())
# Out:
#              0
# InvoiceNo    0
# StockCode    0
# Description  0
# Quantity     0
# InvoiceDate  0
# UnitPrice    0
# CustomerID   0
# Country      0

# %%
pd.DataFrame(df_filtered.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  float64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 27.9+ MB
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Simpan data yang telah dihapus ke dalam file Excel
df_filtered.to_excel('/content/drive/MyDrive/Dataset Data Analyst/Online_Retail_DropNA.xlsx', index=False)

# %%
df_filtered.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1  536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
#melihat plot box qty range angkanya
ax = df_filtered['Quantity'].plot.box(
    showfliers=False,
    grid=True,
    figsize=(10, 7)
)

ax.set_ylabel('Order Quantity')
ax.set_title('Quantity Distribution')

plt.suptitle("")
plt.show()

# %%
#fungsi df loc yaitu digunakan untuk menyeleksi data yang berada ditengah atau diantara serangkaian data pada dtaframe.
#disini menyeleksi qty lebih besar dari 0
df_filtered = df_filtered.loc[df['Quantity']> 0 ]

# %%
#melihat kolom setelah di update
df_filtered.shape
# Out:
# (397924, 8)

# %%
#Melakukan Filter Data Berdasarkan Waktu 
monthly_orders_df = df_filtered.set_index('InvoiceDate')['InvoiceNo'].resample('M').nunique()

# %%
#melihat jumlah transaksi (invoice no) tiap bulannya
print(monthly_orders_df)
# Out:
# InvoiceDate
# 2010-12-31    1400
# 2011-01-31     987
# 2011-02-28     998
# 2011-03-31    1321
# 2011-04-30    1149
# 2011-05-31    1555
# 2011-06-30    1393
# 2011-07-31    1331
# 2011-08-31    1281
# 2011-09-30    1756
# 2011-10-31    1929
# 2011-11-30    2658
# 2011-12-31     778
# Freq: M, Name: InvoiceNo, dtype: int64

# %%
pd.DataFrame(monthly_orders_df)
# Out:
#              InvoiceNo
# InvoiceDate
# 2010-12-31        1400
# 2011-01-31         987
# 2011-02-28         998
# 2011-03-31        1321
# 2011-04-30        1149
# 2011-05-31        1555
# 2011-06-30        1393
# 2011-07-31        1331
# 2011-08-31        1281
# 2011-09-30        1756
# 2011-10-31        1929
# 2011-11-30        2658
# 2011-12-31         778

# %%
ax = pd.DataFrame(monthly_orders_df.values).plot( #membuat kertas putihnya
    grid=True,
    figsize=(10,5),
    legend=True
)

ax.set_xlabel('Date')
ax.set_ylabel('Number Of Orders/Invoices')
ax.set_title('Total Number Of Orders Over Time')
ax.legend('Total Number od Orders' )

plt.xticks( #membuat name pada fig x
    range(len(monthly_orders_df.index)), 
    [x.strftime('%m.%Y') for x in monthly_orders_df.index], #.strftime('%m.%Y') https://www.geeksforgeeks.org/python-strftime-function/
    rotation=20
)

plt.show()

# %%
invoice_dates = df_filtered.loc[
    df_filtered['InvoiceDate'] > '2011-12-01',
    'InvoiceDate'
]

# %%
print('Min date: %s\nMax date: %s' % (invoice_dates.min(), invoice_dates.max()))
# Out:
# Min date: 2011-12-01 08:33:00
# Max date: 2011-12-09 12:50:00

# %%
df_filtered.loc[df_filtered['InvoiceDate'] < '2011-12-01'].shape
# Out:
# (380620, 8)

# %%
df_filtered = df_filtered.loc[df_filtered['InvoiceDate'] < '2011-12-01']

# %%
df_filtered.shape
# Out:
# (380620, 8)

# %%
monthly_orders_df = df_filtered.set_index('InvoiceDate')['InvoiceNo'].resample('M').nunique()

# %%
monthly_orders_df
# Out:
# InvoiceDate
# 2010-12-31    1400
# 2011-01-31     987
# 2011-02-28     998
# 2011-03-31    1321
# 2011-04-30    1149
# 2011-05-31    1555
# 2011-06-30    1393
# 2011-07-31    1331
# 2011-08-31    1281
# 2011-09-30    1756
# 2011-10-31    1929
# 2011-11-30    2658
# Freq: M, Name: InvoiceNo, dtype: int64

# %%
ax = pd.DataFrame(monthly_orders_df.values).plot( #membuat kertas putihnya
    grid=True,
    figsize=(10,5),
    legend=False
)

ax.set_xlabel('Date')
ax.set_ylabel('Number Of Orders/Invoices')
ax.set_title('Total Number Of Orders Over Time')

plt.xticks( #membuat label X
    range(len(monthly_orders_df.index)), 
    [x.strftime('%m.%Y') for x in monthly_orders_df.index], #.strftime('%m.%Y') https://www.geeksforgeeks.org/python-strftime-function/
    rotation=45
)

plt.show()

# %%
 df_filtered['Sales'] = df_filtered['Quantity'] * df_filtered['UnitPrice']

# %%
monthly_revenue_df = df_filtered.set_index('InvoiceDate')['Sales'].resample('M').sum()
monthly_revenue_df
# Out:
# InvoiceDate
# 2010-12-31     572713.890
# 2011-01-31     569445.040
# 2011-02-28     447137.350
# 2011-03-31     595500.760
# 2011-04-30     469200.361
# 2011-05-31     678594.560
# 2011-06-30     661213.690
# 2011-07-31     600091.011
# 2011-08-31     645343.900
# 2011-09-30     952838.382
# 2011-10-31    1039318.790
# 2011-11-30    1161817.380
# Freq: M, Name: Sales, dtype: float64

# %%
pd.DataFrame(monthly_revenue_df)
# Out:
#                    Sales
# InvoiceDate
# 2010-12-31    572713.890
# 2011-01-31    569445.040
# 2011-02-28    447137.350
# 2011-03-31    595500.760
# 2011-04-30    469200.361
# 2011-05-31    678594.560
# 2011-06-30    661213.690
# 2011-07-31    600091.011
# 2011-08-31    645343.900
# 2011-09-30    952838.382
# 2011-10-31   1039318.790
# 2011-11-30   1161817.380

# %%
ax = pd.DataFrame(monthly_revenue_df.values).plot(
    grid=True,
    figsize=(10,7),
    legend=False
)

ax.set_xlabel('date')
ax.set_ylabel('sales')
ax.set_title('Total Revenue Over Time')

ax.set_ylim([0, max(monthly_revenue_df.values)+100000])

plt.xticks(
    range(len(monthly_revenue_df.index)), 
    [x.strftime('%m.%Y') for x in monthly_revenue_df.index], 
    rotation=45
)

plt.show()

# %%
invoice_customer_df = df_filtered.groupby(
    ['InvoiceNo', 'InvoiceDate']
).agg({
    'Sales': sum,
    'CustomerID': max,
    'Country': max,
}).reset_index()

# %%
invoice_customer_df.head(10)
# Out:
#    InvoiceNo         InvoiceDate   Sales  CustomerID         Country
# 0   536365.0 2010-12-01 08:26:00  139.12     17850.0  United Kingdom
# 1   536366.0 2010-12-01 08:28:00   22.20     17850.0  United Kingdom
# 2   536367.0 2010-12-01 08:34:00  278.73     13047.0  United Kingdom
# 3   536368.0 2010-12-01 08:34:00   70.05     13047.0  United Kingdom
# 4   536369.0 2010-12-01 08:35:00   17.85     13047.0  United Kingdom
# 5   536370.0 2010-12-01 08:45:00  855.86     12583.0          France
# 6   536371.0 2010-12-01 09:00:00  204.00     13748.0  United Kingdom
# 7   536372.0 2010-12-01 09:01:00   22.20     17850.0  United Kingdom
# 8   536373.0 2010-12-01 09:02:00  259.86     17850.0  United Kingdom
# 9   536374.0 2010-12-01 09:09:00  350.40     15100.0  United Kingdom

# %%
monthly_repeat_customers_df = invoice_customer_df.set_index('InvoiceDate').groupby([
    pd.Grouper(freq='M'), 'CustomerID'
]).filter(lambda x: len(x) > 1).resample('M').nunique()['CustomerID']

monthly_repeat_customers_df
# Out:
# InvoiceDate
# 2010-12-31    263
# 2011-01-31    153
# 2011-02-28    153
# 2011-03-31    203
# 2011-04-30    170
# 2011-05-31    281
# 2011-06-30    220
# 2011-07-31    227
# 2011-08-31    198
# 2011-09-30    272
# 2011-10-31    324
# 2011-11-30    541
# Freq: M, Name: CustomerID, dtype: int64

# %%
monthly_unique_customer = df_filtered.set_index ('InvoiceDate')['CustomerID'].resample('M').nunique()
monthly_unique_customer
# Out:
# InvoiceDate
# 2010-12-31     885
# 2011-01-31     741
# 2011-02-28     758
# 2011-03-31     974
# 2011-04-30     856
# 2011-05-31    1056
# 2011-06-30     991
# 2011-07-31     949
# 2011-08-31     935
# 2011-09-30    1266
# 2011-10-31    1364
# 2011-11-30    1665
# Freq: M, Name: CustomerID, dtype: int64

# %%
monthly_repeat_percentage = monthly_repeat_customers_df/monthly_unique_customer*100.0
monthly_repeat_percentage
# Out:
# InvoiceDate
# 2010-12-31    29.717514
# 2011-01-31    20.647773
# 2011-02-28    20.184697
# 2011-03-31    20.841889
# 2011-04-30    19.859813
# 2011-05-31    26.609848
# 2011-06-30    22.199798
# 2011-07-31    23.919916
# 2011-08-31    21.176471
# 2011-09-30    21.484992
# 2011-10-31    23.753666
# 2011-11-30    32.492492
# Freq: M, Name: CustomerID, dtype: float64

# %%
ax = pd.DataFrame(monthly_repeat_customers_df.values).plot(
    figsize=(11,7), color='orange'
)

pd.DataFrame(monthly_unique_customer.values).plot(
    ax=ax,
    grid=True
)


ax2 = pd.DataFrame(monthly_repeat_percentage.values).plot.bar(
    ax=ax,
    grid=True,
    secondary_y=True,
    color='green',
    alpha=0.2
)

ax.set_xlabel('date')
ax.set_ylabel('number of customers')
ax.set_title('Number of All vs. Repeat Customers Over Time')

ax2.set_ylabel('percentage (%)')

ax.legend(['Repeat Customers', 'All Customers'])
ax2.legend(['Percentage of Repeat'], loc='upper right')

ax.set_ylim([0, monthly_unique_customer.values.max()+100])
ax2.set_ylim([0, 100])

plt.xticks(
    range(len(monthly_repeat_customers_df.index)), 
    [x.strftime('%m.%Y') for x in monthly_repeat_customers_df.index], 
    rotation=20
)

plt.show()

# %%
date_item_df = pd.DataFrame(
    df_filtered.set_index('InvoiceDate').groupby([
        pd.Grouper(freq='M'), 'StockCode'
    ])['Quantity'].sum()
)
date_item_df
# Out:
#                           Quantity
# InvoiceDate StockCode
# 2010-12-31  10002.0          224.0
#             10120.0           16.0
#             10125.0          143.0
#             10133.0          123.0
#             10135.0          366.0
# ...                            ...
# 2011-11-30  BANK CHARGES       2.0
#             C2                22.0
#             DOT                4.0
#             M               3893.0
#             POST             460.0
#
# [28234 rows x 1 columns]

# %%
# Rank items by the last month sales
last_month_sorted_df = date_item_df.loc['2011-11-30'].sort_values(
    by='Quantity', ascending=False
).reset_index()

last_month_sorted_df
# Out:
#      InvoiceDate StockCode  Quantity
# 0     2011-11-30   84826.0   12551.0
# 1     2011-11-30   23084.0   12393.0
# 2     2011-11-30   22197.0    8458.0
# 3     2011-11-30   22086.0    5919.0
# 4     2011-11-30    85099B    5678.0
# ...          ...       ...       ...
# 2690  2011-11-30   90159.0       1.0
# 2691  2011-11-30   90154.0       1.0
# 2692  2011-11-30   20695.0       1.0
# 2693  2011-11-30   21391.0       1.0
# 2694  2011-11-30   84522.0       1.0
#
# [2695 rows x 3 columns]

# %%
# Regroup for top 5 items
date_item_df = pd.DataFrame(
    df.loc[
        df['StockCode'].isin([23084, 84826, 22197, 22086, '85099B'])
    ].set_index('InvoiceDate').groupby([
        pd.Grouper(freq='M'), 'StockCode'
    ])['Quantity'].sum()
)
date_item_df
# Out:
#                        Quantity
# InvoiceDate StockCode
# 2010-12-31  22086.0      2453.0
#             22197.0      2731.0
#             84826.0       306.0
#             85099B       2126.0
# 2011-01-31  22086.0        24.0
#             22197.0      1809.0
#             84826.0       480.0
#             85099B       2639.0
# 2011-02-28  22086.0         5.0
#             22197.0      2663.0
#             84826.0        66.0
#             85099B       3078.0
# 2011-03-31  22086.0        87.0
#             22197.0      2798.0
#             84826.0        60.0
#             85099B       5281.0
# 2011-04-30  22086.0       -27.0
#             22197.0      1856.0
#             84826.0         1.0
#             85099B       2452.0
# 2011-05-31  22086.0        17.0
#             22197.0      6848.0
#             23084.0      1131.0
#             85099B       3617.0
# 2011-06-30  22086.0       344.0
#             22197.0      2092.0
#             23084.0      1693.0
# ...

# %%
trending_itmes_df = date_item_df.reset_index().pivot('InvoiceDate','StockCode').fillna(0)

trending_itmes_df = trending_itmes_df.reset_index()
trending_itmes_df = trending_itmes_df.set_index('InvoiceDate')
trending_itmes_df.columns = trending_itmes_df.columns.droplevel(0)

trending_itmes_df
# Out:
# StockCode    22086.0  22197.0  23084.0  84826.0  85099B
# InvoiceDate
# 2010-12-31    2453.0   2731.0      0.0    306.0  2126.0
# 2011-01-31      24.0   1809.0      0.0    480.0  2639.0
# 2011-02-28       5.0   2663.0      0.0     66.0  3078.0
# 2011-03-31      87.0   2798.0      0.0     60.0  5281.0
# 2011-04-30     -27.0   1856.0      0.0      1.0  2452.0
# 2011-05-31      17.0   6848.0   1131.0      0.0  3617.0
# 2011-06-30     344.0   2092.0   1693.0      4.0  3676.0
# 2011-07-31     377.0   1862.0    318.0      2.0  3126.0
# 2011-08-31     370.0   5416.0   1783.0     72.0  5401.0
# 2011-09-30    2106.0   4153.0    196.0      0.0  4267.0
# 2011-10-31    3189.0   5865.0   6344.0     11.0  4803.0
# 2011-11-30    7868.0  12159.0  14883.0  12551.0  5807.0
# 2011-12-31    2089.0   6198.0   4298.0     92.0  1090.0

# %%
ax = pd.DataFrame(trending_itmes_df.values).plot(
    figsize=(10,7),
    grid=True,
)

ax.set_ylabel('number of purchases')
ax.set_xlabel('date')
ax.set_title('Item Trends over Time')

ax.legend(trending_itmes_df.columns, loc='upper left')

plt.xticks(
    range(len(trending_itmes_df.index)), 
    [x.strftime('%m.%Y') for x in trending_itmes_df.index], 
    rotation=20
)

plt.show()
